# %%
import pandas as pd
import numpy as np

# %%
# Load Datasets

df_2012 = pd.read_csv(r"D:\Data_D\TMU\MRP\1.0.Dataset\Socio_Economic\Census_Data_-_Selected_socioeconomic_indicators_in_Chicago,_2008_–_2012_20260425.csv")
df_2020 = pd.read_csv(r"D:\Data_D\TMU\MRP\1.0.Dataset\Socio_Economic\Chicago_2020_sdoh.csv")

# %% [markdown]
# 2008 - 2012

# %%
print(df_2012.shape)
print(df_2012.columns)
# Out:
# (78, 9)
# Index(['Community Area Number', 'COMMUNITY AREA NAME',
#        'PERCENT OF HOUSING CROWDED', 'PERCENT HOUSEHOLDS BELOW POVERTY',
#        'PERCENT AGED 16+ UNEMPLOYED',
#        'PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA',
#        'PERCENT AGED UNDER 18 OR OVER 64', 'PER CAPITA INCOME ',
#        'HARDSHIP INDEX'],
#       dtype='object')

# %%
df_2012.tail()
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
# 77                    NaN             CHICAGO                         4.7
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 73                               3.4                          8.7
# 74                              13.2                         15.0
# 75                              15.4                          7.1
# 76                              18.2                          9.2
# 77                              19.7                         12.9
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 73                                           4.3
# ...

# %%
df_2012 = df_2012.dropna(subset=['Community Area Number'])
print(df_2012.shape)
# Out:
# (77, 9)

# %%
df_2012.head()
# Out:
#    Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# ...

# %%
df_2012.tail()
# Out:
#     Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 72                   73.0   Washington Height                         1.1
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 72                              16.9                         20.8
# 73                               3.4                          8.7
# 74                              13.2                         15.0
# 75                              15.4                          7.1
# 76                              18.2                          9.2
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 72                                          13.7
# ...

# %%
df_2012 = df_2012[[
    'Community Area Number',
    'COMMUNITY AREA NAME',
    'PER CAPITA INCOME ',
    'PERCENT AGED 16+ UNEMPLOYED',
    'PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA'
]]


df_2012.head(1)
# Out:
#    Community Area Number COMMUNITY AREA NAME  PER CAPITA INCOME   \
# 0                    1.0         Rogers Park               23939
#
#    PERCENT AGED 16+ UNEMPLOYED  PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA
# 0                          8.7                                          18.2

# %%
df_2012 = df_2012.rename(columns={
    'Community Area Number': 'community_area',
    'COMMUNITY AREA NAME': 'community_name',
    'PER CAPITA INCOME ': 'per_capita_income',
    'PERCENT AGED 16+ UNEMPLOYED': 'unemployment_rate',
    'PERCENT HOUSEHOLDS BELOW POVERTY': 'poverty_rate',
    'PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA': 'no_highschool_pct'
})

df_2012.head(1)
# Out:
#    community_area community_name  per_capita_income  unemployment_rate  \
# 0             1.0    Rogers Park              23939                8.7
#
#    no_highschool_pct
# 0               18.2

# %%
df_2012.dtypes
# Out:
# community_area       float64
# community_name        object
# per_capita_income      int64
# unemployment_rate    float64
# no_highschool_pct    float64
# dtype: object

# %%
df_2012['community_area'] = df_2012['community_area'].astype(int)
print(df_2012.dtypes)
print(df_2012.shape)
# Out:
# community_area         int64
# community_name        object
# per_capita_income      int64
# unemployment_rate    float64
# no_highschool_pct    float64
# dtype: object
# (77, 5)

# %% [markdown]
# 2020

# %%
print(df_2020.columns)
print(df_2020.shape)
# Out:
# Index(['area_num_1', 'community', 'shape_area', 'shape_len', 'districtno',
#        'district', 'TOT_POP', '2000_POP', '2010_POP', 'UND5',
#        ...
#        'ARABIC', 'KOREAN', 'OTHASIAN', 'OTHER_EURO', 'OTHUNSPEC', '2000_WHITE',
#        '2000_HISP', '2000_BLACK', '2000_ASIAN', '2000_OTHER'],
#       dtype='object', length=232)
# (77, 232)

# %%
print(df_2020['area_num_1'])
print(df_2020['community'])
print(df_2020['INCPERCAP'])
print(df_2020['Unemprt'])
print(df_2020['LT_HS'])
print(df_2020['TOT_POP'])
# Out:
# 0     35
# 1     36
# 2     37
# 3     38
# 4     39
#       ..
# 72    74
# 73    75
# 74    76
# 75    77
# 76     9
# Name: area_num_1, Length: 77, dtype: int64
# 0             DOUGLAS
# 1             OAKLAND
# 2         FULLER PARK
# 3     GRAND BOULEVARD
# 4             KENWOOD
#            ...
# 72    MOUNT GREENWOOD
# 73        MORGAN PARK
# 74              OHARE
# 75          EDGEWATER
# 76        EDISON PARK
# Name: community, Length: 77, dtype: object
# 0     26096
# 1     23388
# 2     16519
# 3     29437
# 4     46785
#       ...
# 72    40074
# 73    34873
# 74    31267
# 75    43457
# 76    59666
# Name: INCPERCAP, Length: 77, dtype: int64
# 0     13.087248
# 1     15.328070
# 2     23.622047
# 3     13.743637
# 4     10.545867
#         ...
# 72     4.064876
# 73    10.486669
# 74     5.208197
# 75     5.012482
# 76     1.558276
# Name: Unemprt, Length: 77, dtype: float64
# 0     1514
# 1      404
# 2      373
# 3     2030
# 4      752
#       ...
# 72     453
# ...

# %%
df_2020['no_highschool_pct'] = (df_2020['LT_HS']/ df_2020['TOT_POP'])*100
df_2020.head(1)
# Out:
#    area_num_1 community    shape_area    shape_len  districtno    district  \
# 0          35   DOUGLAS  4.600462e+07  31027.05451           7  South Side
#
#    TOT_POP  2000_POP  2010_POP  UND5  ...  KOREAN  OTHASIAN  OTHER_EURO  \
# 0    21325     26470     18238  1107  ...     145       571        1290
#
#    OTHUNSPEC  2000_WHITE  2000_HISP  2000_BLACK  2000_ASIAN  2000_OTHER  \
# 0        555        1745        295       22635        1390         405
#
#    no_highschool_pct
# 0           7.099648
#
# [1 rows x 233 columns]

# %%
df_2020 = df_2020[[
    'area_num_1',
    'community',
    'INCPERCAP',
    'Unemprt',
    'no_highschool_pct'
]]

df_2020.head(1)
# Out:
#    area_num_1 community  INCPERCAP    Unemprt  no_highschool_pct
# 0          35   DOUGLAS      26096  13.087248           7.099648

# %%
df_2020 = df_2020.rename(columns={
    'area_num_1': 'community_area',
    'community': 'community_name',
    'INCPERCAP': 'per_capita_income',
    'Unemprt': 'unemployment_rate'
})

df_2020.head()
# Out:
#    community_area   community_name  per_capita_income  unemployment_rate  \
# 0              35          DOUGLAS              26096          13.087248
# 1              36          OAKLAND              23388          15.328070
# 2              37      FULLER PARK              16519          23.622047
# 3              38  GRAND BOULEVARD              29437          13.743637
# 4              39          KENWOOD              46785          10.545867
#
#    no_highschool_pct
# 0           7.099648
# 1           5.590148
# 2          15.580618
# 3           9.140439
# 4           4.188482

# %%
df_2020.dtypes
# Out:
# community_area         int64
# community_name        object
# per_capita_income      int64
# unemployment_rate    float64
# no_highschool_pct    float64
# dtype: object

# %%
df_2020.shape
# Out:
# (77, 5)

# %% [markdown]
# Adding Year Column to each dataset

# %%
df_2012['year'] = '2012'
df_2020['year'] = '2020'

df_2012.head(1)
# Out:
#    community_area community_name  per_capita_income  unemployment_rate  \
# 0               1    Rogers Park              23939                8.7
#
#    no_highschool_pct  year
# 0               18.2  2012

# %%
df_2020.head(1)
# Out:
#    community_area community_name  per_capita_income  unemployment_rate  \
# 0              35        DOUGLAS              26096          13.087248
#
#    no_highschool_pct  year
# 0           7.099648  2020

# %%
print(df_2012.shape)

print(df_2020.shape)
# Out:
# (77, 6)
# (77, 6)

# %%
socio_economic = pd.concat([df_2012, df_2020], ignore_index=True)
socio_economic.head(1)
# Out:
#    community_area community_name  per_capita_income  unemployment_rate  \
# 0               1    Rogers Park              23939                8.7
#
#    no_highschool_pct  year
# 0               18.2  2012

# %%
socio_economic["community_name"] = socio_economic["community_name"].str.lower().fillna("")

# %%
socio_economic.head(1)
# Out:
#    community_area community_name  per_capita_income  unemployment_rate  \
# 0               1    rogers park              23939                8.7
#
#    no_highschool_pct  year
# 0               18.2  2012

# %%
socio_economic.tail(1)
# Out:
#      community_area community_name  per_capita_income  unemployment_rate  \
# 153               9    edison park              59666           1.558276
#
#      no_highschool_pct  year
# 153           3.258033  2020

# %%
socio_economic.shape
# Out:
# (154, 6)

# %%
socio_economic = socio_economic.sort_values(by=['community_area', 'year'])
socio_economic.head(1)
# Out:
#    community_area community_name  per_capita_income  unemployment_rate  \
# 0               1    rogers park              23939                8.7
#
#    no_highschool_pct  year
# 0               18.2  2012

# %%
socio_economic.tail(1)
# Out:
#      community_area community_name  per_capita_income  unemployment_rate  \
# 152              77      edgewater              43457           5.012482
#
#      no_highschool_pct  year
# 152           7.151902  2020

# %%
socio_economic.shape
# Out:
# (154, 6)

# %%
socio_economic.columns
# Out:
# Index(['community_area', 'community_name', 'per_capita_income',
#        'unemployment_rate', 'no_highschool_pct', 'year'],
#       dtype='object')

# %%
socio_economic.dtypes
# Out:
# community_area         int64
# community_name        object
# per_capita_income      int64
# unemployment_rate    float64
# no_highschool_pct    float64
# year                  object
# dtype: object

# %%
socio_economic.to_csv(r"D:\Data_D\TMU\MRP\1.0.Dataset\Socio_Economic\Socio_Economic_Final.csv", index=False)
